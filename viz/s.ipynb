# %%
import pandas as pd
df = pd.read_csv('../CSVs/01.csv')
df
# Out:
#                                            wine_name  ratings_average  \
# 0                     Brunello di Montalcino Riserva              4.9
# 1             L'Extravagant de Doisy-Daëne Sauternes              4.9
# 2                                            Pomerol              4.8
# 3  Le Mesnil Blanc de Blancs (Cuvée S) Brut Champ...              4.8
# 4                Pauillac (Premier Grand Cru Classé)              4.8
# 5      Grand Vin Pauillac (Premier Grand Cru Classé)              4.8
# 6                                            Toscana              4.8
# 7                                          Sauternes              4.8
# 8                                            Toscana              4.8
# 9                                            Toscana              4.8
#
#    ratings_count  rating_per_price  price_euros
# 0             35              0.25      1970.05
# 1             32              1.23       397.50
# 2           1190              0.08      6300.00
# ...
